# %%
## What to do with missing values??

# detect missing value

print(df.isnull().sum())

# drop rows with missing values

df.dropna(inplace=True)

# fill missing values

df.fillna(value='default_vawlue', inplace=True)

## what to do with duplicate values??

df.drop_duplicates(inplace=True)

## fix data types??

df['data_column'] = pd.to_datetime(df['data_column'])

df['numeric_column'] = pd.to_numeric(df['numeric_column'], errors='coerce')

## standardise data ??
#strip spaces
#capitalisation

df['name'] = df['name'].str.lower().str.strip()

#use regex to standaerdised formatting and make use data is represented uniformly

## drop unnecessary columns

df.drop(columns=['user_id'], inplace=True)

##dealing with outlying data


01 = df['value'] .quantile(0.25)
03 = df['value'] .quantile(0.75)
IQR = Q3 - Q1
df = df[(df['value'] >= (Q1 - 1.5 * IQR)) & (df['value'] <= (Q3 + 1.5 * IQR))]
